# %%
from tqdm.notebook import tqdm
import numpy as np
import pandas as pd

import plotly.graph_objects as go

import datetime
from pathlib import Path

import intake

from sklearn.model_selection import train_test_split

from tensorflow.keras.regularizers import l2
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv3D, Activation, BatchNormalization, \
                                     Dropout, Flatten, Dense
# Out:
# 2024-04-19 10:07:17.566179: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-19 10:07:18.818317: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
target = 'tree_name'
df = pd.read_csv("data/Borough_tree_list_2021July.csv", usecols=[target])

# %%
df = df.dropna(subset=target)

# %%
def process_data(filepaths, selected_bands):
    for filepath in tqdm(filepaths):
        save_path = Path(filepath.parent).joinpath(f'processed_{filepath.name}')

        if save_path.is_file():
            continue
            
        with open(filepath, 'rb') as f:
            raw_data = np.load(filepath)
    
        for band in selected_bands:
            zero_fraction = (raw_data[band] == 0).sum()/raw_data[band].size
            
            if zero_fraction < 0.6:
                raw_data[band] = np.where(
                    raw_data[band] > 0, raw_data[band], raw_data[band][raw_data[band] > 0].mean())
            else:
                raise ValueError(f'Too many zeros: {zero_fraction:.2f} of data. '
                                 'Modify the condition or employ a different strategy.')
                
        data = raw_data.view((float, len(raw_data.dtype.names)))
        
        with open(save_path, 'wb') as f:
            np.save(f, data)

# %%
selected_bands = [f'B{x}' for x in range(2, 9)] + ['B8A', 'B11', 'B12', 'TCI_R', 'TCI_G', 'TCI_B']

# %%
filepaths = sorted(list(Path('london').glob(f'london*.npy')), 
                   key=lambda s: int(s.stem.split('_')[-1]))
process_data(filepaths, selected_bands)
# Out:
#   0%|          | 0/34 [00:00<?, ?it/s]

# %%
class Conv3DModelCreator:
    def normalise(self, a, p=1):
        upper = np.percentile(a, 100-p)
        lower = np.percentile(a, p)
    
        bounded_a = np.where(a > upper, np.median(a), a)
        bounded_a = np.where(a < lower, np.median(a), bounded_a)
        
        scaled_a = (bounded_a - lower)/(upper - lower)
        return scaled_a
        
    def split_and_preprocess(self, y, X, random_state=42):
        """Split and max scale."""
        X_train, X_test, y_train, y_test = train_test_split(
            X, y, test_size=0.1, random_state=random_state)

        for i in range(X_train.shape[-1]):
            X_train[...,i] = self.normalise(X_train[...,i])
            X_test[...,i] = self.normalise(X_test[...,i])
        
        return X_train, X_test, y_train, y_test

    def build_model_3d(self, num_classes, input_size):
        m = tf.keras.Sequential()
        m.add(Input(input_size))
        for i in range(3): 
            m.add(Conv3D(
                16, 
                strides=1, 
                padding='same',
                kernel_size=(3, 3, 3),
                # kernel_initializer='he_normal',
                # kernel_regularizer=l2(1e-6)
            ))
            m.add(BatchNormalization(axis=-1))
            m.add(Activation('relu'))
            # m.add(Dropout(0.25))
            
        m.add(Flatten())
        m.add(Dense(32, 
                    # kernel_initializer='he_normal', 
                    # kernel_regularizer=l2(1e-6)
                   )
             )
        m.add(BatchNormalization(axis=-1))
        m.add(Activation('relu'))
        # m.add(Dropout(0.25))
        
        m.add(Dense(
            num_classes, 
            activation='sigmoid', 
            # kernel_initializer='glorot_uniform',
            # kernel_regularizer=l2(1e-6)
        ))

        opt = tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
        loss = tf.keras.losses.CategoricalCrossentropy()
        m.compile(
            optimizer=opt,
            loss=loss,
            metrics=['accuracy']
        )
        return m
        
    def run(self, y, X, num_classes, model_name):
        X_train, X_test, y_train, y_test = self.split_and_preprocess(y, X)
        model_path = Path('models').joinpath(model_name)

        if model_path.is_file():
            model = tf.keras.models.load_model(model_path)
        else:
            model = self.build_model_3d(num_classes, X_train.shape[1:])
            
        model.fit(X_train, y_train, epochs=10, verbose=1, batch_size=4,
                  validation_data=(X_test, y_test))
        model.save(model_path)

# %%
# %%time
all_data = []

n_chunks = 50000

labels = pd.get_dummies(df).to_numpy()

chunks = [labels[i: i + n_chunks] for i in range(0, labels.shape[0], n_chunks)]

model_name = f'conv_london_spring.keras'

for i, chunk in enumerate(chunks):
    filepaths = sorted(list(Path('london').glob(f'processed*_{i}.npy')))
    all_parts = []
    for filepath in filepaths:
        with open(filepath, 'rb') as f:
            data = np.load(f)
        all_parts.append(data)
    features = np.stack(all_parts, axis=3)

    Conv3DModelCreator().run(chunk, features, labels.shape[1], model_name)
# Out:
# Epoch 1/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 36s 3ms/step - accuracy: 0.2339 - loss: 2.7357 - val_accuracy: 0.2624 - val_loss: 2.5497
# Epoch 2/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.2462 - loss: 2.6311 - val_accuracy: 0.2528 - val_loss: 2.5808
# Epoch 3/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.2531 - loss: 2.6180 - val_accuracy: 0.2648 - val_loss: 2.5684
# Epoch 4/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.2602 - loss: 2.5940 - val_accuracy: 0.2692 - val_loss: 2.5169
# Epoch 5/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.2639 - loss: 2.5802 - val_accuracy: 0.2720 - val_loss: 2.5292
# Epoch 6/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 44s 4ms/step - accuracy: 0.2610 - loss: 2.5800 - val_accuracy: 0.2694 - val_loss: 2.5295
# Epoch 7/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.2644 - loss: 2.5640 - val_accuracy: 0.2682 - val_loss: 2.5300
# Epoch 8/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 42s 4ms/step - accuracy: 0.2668 - loss: 2.5604 - val_accuracy: 0.2698 - val_loss: 2.5195
# Epoch 9/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 42s 4ms/step - accuracy: 0.2653 - loss: 2.5562 - val_accuracy: 0.2568 - val_loss: 2.4842
# Epoch 10/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.2655 - loss: 2.5542 - val_accuracy: 0.2756 - val_loss: 2.4840
# Epoch 1/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 42s 4ms/step - accuracy: 0.2194 - loss: 2.6915 - val_accuracy: 0.2388 - val_loss: 2.5738
# Epoch 2/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.2297 - loss: 2.6285 - val_accuracy: 0.2356 - val_loss: 2.5568
# Epoch 3/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.2338 - loss: 2.6081 - val_accuracy: 0.2430 - val_loss: 2.5882
# Epoch 4/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 42s 4ms/step - accuracy: 0.2340 - loss: 2.5988 - val_accuracy: 0.2374 - val_loss: 2.5799
# Epoch 5/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.2369 - loss: 2.5947 - val_accuracy: 0.2376 - val_loss: 2.5450
# Epoch 6/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.2368 - loss: 2.5867 - val_accuracy: 0.2510 - val_loss: 2.5338
# Epoch 7/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 43s 4ms/step - accuracy: 0.2391 - loss: 2.5830 - val_accuracy: 0.2548 - val_loss: 2.5091
# Epoch 8/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 44s 4ms/step - accuracy: 0.2401 - loss: 2.5744 - val_accuracy: 0.2510 - val_loss: 2.5153
# Epoch 9/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.2390 - loss: 2.5766 - val_accuracy: 0.2488 - val_loss: 2.5081
# Epoch 10/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 42s 4ms/step - accuracy: 0.2415 - loss: 2.5633 - val_accuracy: 0.2572 - val_loss: 2.4925
# Epoch 1/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.1616 - loss: 2.6793 - val_accuracy: 0.2120 - val_loss: 2.5170
# Epoch 2/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 42s 4ms/step - accuracy: 0.1775 - loss: 2.6131 - val_accuracy: 0.1990 - val_loss: 2.5036
# Epoch 3/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 42s 4ms/step - accuracy: 0.1887 - loss: 2.5946 - val_accuracy: 0.1974 - val_loss: 2.5181
# Epoch 4/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.1899 - loss: 2.5783 - val_accuracy: 0.2198 - val_loss: 2.4648
# Epoch 5/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 42s 4ms/step - accuracy: 0.1927 - loss: 2.5708 - val_accuracy: 0.2206 - val_loss: 2.4458
# Epoch 6/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.1935 - loss: 2.5544 - val_accuracy: 0.2338 - val_loss: 2.4364
# Epoch 7/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 42s 4ms/step - accuracy: 0.1989 - loss: 2.5507 - val_accuracy: 0.2282 - val_loss: 2.4592
# Epoch 8/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.2062 - loss: 2.5410 - val_accuracy: 0.2178 - val_loss: 2.4575
# Epoch 9/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.2037 - loss: 2.5428 - val_accuracy: 0.2306 - val_loss: 2.4405
# Epoch 10/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.1997 - loss: 2.5335 - val_accuracy: 0.2330 - val_loss: 2.4258
# Epoch 1/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.2426 - loss: 2.6431 - val_accuracy: 0.2908 - val_loss: 2.4527
# Epoch 2/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.2701 - loss: 2.5633 - val_accuracy: 0.2876 - val_loss: 2.4902
# Epoch 3/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.2719 - loss: 2.5525 - val_accuracy: 0.2834 - val_loss: 2.4630
# Epoch 4/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 46s 4ms/step - accuracy: 0.2744 - loss: 2.5381 - val_accuracy: 0.2998 - val_loss: 2.4185
# Epoch 5/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 47s 4ms/step - accuracy: 0.2765 - loss: 2.5226 - val_accuracy: 0.2934 - val_loss: 2.4448
# Epoch 6/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 47s 4ms/step - accuracy: 0.2814 - loss: 2.5251 - val_accuracy: 0.3086 - val_loss: 2.4041
# Epoch 7/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 47s 4ms/step - accuracy: 0.2846 - loss: 2.5018 - val_accuracy: 0.3032 - val_loss: 2.3901
# Epoch 8/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 47s 4ms/step - accuracy: 0.2853 - loss: 2.5109 - val_accuracy: 0.3090 - val_loss: 2.4186
# Epoch 9/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 47s 4ms/step - accuracy: 0.2886 - loss: 2.5042 - val_accuracy: 0.3028 - val_loss: 2.4062
# Epoch 10/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 43s 4ms/step - accuracy: 0.2945 - loss: 2.4930 - val_accuracy: 0.3098 - val_loss: 2.3867
# Epoch 1/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 42s 4ms/step - accuracy: 0.2024 - loss: 2.6214 - val_accuracy: 0.2404 - val_loss: 2.5104
# Epoch 2/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.2161 - loss: 2.5794 - val_accuracy: 0.2266 - val_loss: 2.5128
# Epoch 3/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 44s 4ms/step - accuracy: 0.2176 - loss: 2.5763 - val_accuracy: 0.2392 - val_loss: 2.4995
# Epoch 4/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 43s 4ms/step - accuracy: 0.2234 - loss: 2.5636 - val_accuracy: 0.2430 - val_loss: 2.4919
# Epoch 5/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 49s 4ms/step - accuracy: 0.2199 - loss: 2.5650 - val_accuracy: 0.2148 - val_loss: 2.5472
# Epoch 6/10
# 11250/11250 ━━━━━━━━━━━━━━━━━━━━ 52s 5ms/step - accuracy: 0.2259 - loss: 2.5533 - val_accuracy: 0.2240 - val_loss: 2.5043
# Epoch 7/10
#  2470/11250 ━━━━━━━━━━━━━━━━━━━━ 38s 4ms/step - accuracy: 0.2276 - loss: 2.5404

# %%
# cm = tf.math.confusion_matrix(labels, predictions, num_classes=None)
# px.imshow(
#     np.array(cm),
#     # animation_frame=0,
#     labels=dict(color="Corr coef"),
#     x=cm[0].index,
#     y=cm[0].columns,
#     title='Confusion Matrix',
#     text_auto=True, aspect='auto', zmin=0, height=500
# )

# %%
# target = source.metadata['categories']['multi'] # multi / trinary
# labels = df[target].astype('category').cat.codes
# seasons = ['Spring', 'Summer', 'Autumn', 'Winter']
# all_data = []
# for season in seasons:
#     filepath = sorted(list(Path('seasonal_median').glob(f'{season}.npy')))
#     with open(filepath[0], 'rb') as f:
#         all_data.append(np.load(f))
    
# model_name = f'conv_all_mean_seasons_multi.keras'

# features = np.stack(all_data, axis=3)
# score = ConvModelCreator().run(labels, features, model_name)
# score

# %%
# traces = [go.Scatter(x=seasons, y=seasonal_scores)]
# go.Figure(
#     data=traces,
#     layout={
#         "xaxis": {"title": "Season"},
#         "yaxis": {"title": "Accuracy"},
#         "title": "Conv2d accuracies"}
# )

# %%
# target = source.metadata['categories']['trinary'] # multi / trinary
# labels = df[target].astype('category').cat.codes
# seasons = ['Spring', 'Summer', 'Autumn', 'Winter']
# all_data = []
# for season in tqdm(seasons):
#     filepath = sorted(list(Path('seasonal_median').glob(f'{season}.npy')))
#     with open(filepath[0], 'rb') as f:
#         all_data.append(np.load(f))
    
# model_name = f'conv_all_mean_seasons_trinary.keras'
# score = ConvModelCreator().run(labels, np.stack(all_data, axis=3), model_name)
# score

# %%
# target = source.metadata['categories']['trinary'] # multi / trinary

# mask = df[target] != 'cleared'

# labels = df[target][mask].astype('category').cat.codes

# seasons = ['Spring', 'Summer', 'Autumn', 'Winter']
# all_data = []
# for season in tqdm(seasons):
#     filepath = sorted(list(Path('seasonal_median').glob(f'{season}.npy')))
#     with open(filepath[0], 'rb') as f:
#         data = np.load(f)
#         all_data.append(data[mask])
        
# model_name = f'conv_all_mean_seasons_binary.keras'
# score = ConvModelCreator().run(labels, np.stack(all_data, axis=3), model_name)
# score

# %%
# filepaths = sorted(list(Path('london').glob('*.npy')), key=lambda x: int(x.stem.split('_')[-1]))

# n_chunks = 50000
# chunks = [gdf[i: i + n_chunks] for i in range(0, gdf.shape[0], n_chunks)]
# scores = []

# chunk[target].cat.codes

# for chunk, filepath in tqdm(zip(chunks, filepaths), total=len(filepaths)
#                            ):
#     score = LightModelCreator().run_and_eval(chunk[target].cat.codes, [filepath])
#     scores.append(score)
